# %% [markdown]
# ![Banner](images/dsep-banner.png)
# # **Welcome to the Applied Methods for Social Sciences in Python Workshop**
#
# By John Park, Simran, Barry, etc
#
# In Collaboration with the Division of Data Science's [Data Peer Consulting](https://data.berkeley.edu/ds-peer-consulting)

# %% [markdown]
# ### BEFORE WE BEGIN PLEASE COMPLETE THIS SURVEY
# [TODO](https://forms.gle/rEtcPP1VRRJTsjxQ9)

# %% [markdown]
# ## John Park
# ![John](https://data.berkeley.edu/sites/default/files/styles/width_400/public/john_pic_-_john_park_0.jpg?itok=-kg9pNQg&timestamp=1599267808)
#
# Quick Facts About Me:
#
#     🐻 Senior at Cal
#     🎒 Studying Computer Science and Economics
#     🏢 Interned and returning full-time as an SDE@Amazon
#     📊 Joined the Data Peer Consulting team in Fall 2018
#
# How to Reach Me:
#
#     📮 Email: jhp@berkeley.edu

# %% [markdown]
# ## Simran Sachdev
# ![Simran](https://data.berkeley.edu/sites/default/files/styles/width_400/public/headshot_-_simran_sachdev.jpg?itok=PgdDBm5M&timestamp=1599267430)
#
# Quick Facts About Me:
#
#     🐻 Senior at Cal
#     🎒 Studying Data Science and Applied Math
#     🏢 Data Scientist Intern at Boston Scientific
#     📊 Joined the Data Peer Consulting team in Spring 2020
#
# How to Reach Me:
#
#     📮 Email: ssach@berkeley.edu

# %% [markdown]
# ## Barry's bio (altho do we realllllly need it?)

# %% [markdown]
# ## Spencer's bio (very important)

# %% [markdown]
# <a class="anchor" id="tof"></a>
# ## Table of Contents
#
# Use anchors to set these hyperlinks to jump to certain locations in the notebook.
#
# - [Introduction](#1)
# - [Example](#2)
# - [Reference Sheets](#rs)

# %% [markdown]
# ---
#
# ## Workshop Goals
#
# The goal of this workshop is to cover the fundamental tools offered in Python for applied methods in the social sciences.
#
#     - Learn how to import and modify data in Python via Pandas
#     - Apply OLS and related statistical techniques
#     - Demonstrate a basic example workflow from raw data to analysis
#
# Specifically, we will be working with statsmodels and linearmodels. These packages  provide a wide range of useful statistical tools for the social sciences, including but not limited to least squares, panel methods, mixed models, etc.

# %% [markdown]
# ---
#
# ## Why Python?
#
# Python is one of the most popular general-purpose computing languages, and for good reason. Python's readability, maintainability, and robust community support, especially in the IPython sphere, makes it a strong choice for data science, including for the social sciences.
#
# ### Transitioning from R
#
# Both statsmodels and linearmodels provides support for R-like formula expressions. You can read more about it [here](https://www.statsmodels.org/stable/examples/notebooks/generated/formulas.html).

# %% [markdown]
# ## Introduction
#
# Lets go through a basic example from the [statsmodels documentation](https://www.statsmodels.org/stable/gettingstarted.html). The dataset is a collection of historical data used in support of Andre-Michel Guerry’s 1833 Essay on the Moral Statistics of France.

# %%
### standard imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
# Grab sample data from Statsmodels dataset repo

df = sm.datasets.get_rdataset("Guerry", "HistData").data

# %%
### Note that the data is already in a Pandas DataFrame

type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#     dept Region    Department  Crime_pers  Crime_prop  Literacy  Donations  \
# 0      1      E           Ain       28870       15890        37       5098
# 1      2      N         Aisne       26226        5521        51       8901
# 2      3      C        Allier       26747        7925        13      10973
# 3      4      E  Basses-Alpes       12935        7289        46       2733
# 4      5      E  Hautes-Alpes       17488        8174        69       6962
# ..   ...    ...           ...         ...         ...       ...        ...
# 81    86      W        Vienne       15010        4710        25       8922
# 82    87      C  Haute-Vienne       16256        6402        13      13817
# 83    88      E        Vosges       18835        9044        62       4040
# 84    89      C         Yonne       18006        6516        47       4276
# 85   200    NaN         Corse        2199        4589        49      37015
#
#     Infants  Suicides MainCity  ...  Crime_parents  Infanticide  \
# 0     33120     35039    2:Med  ...             71           60
# 1     14572     12831    2:Med  ...              4           82
# 2     17044    114121    2:Med  ...             46           42
# 3     23018     14238     1:Sm  ...             70           12
# 4     23076     16171     1:Sm  ...             22           23
# ..      ...       ...      ...  ...            ...          ...
# 81    35224     21851    2:Med  ...             20            1
# 82    19940     33497    2:Med  ...             68            6
# 83    14978     33029    2:Med  ...             58           34
# 84    16616     12789    2:Med  ...             32           22
# 85    24743     37016    2:Med  ...             81            2
#
#     Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# 0                69       41         55           46           13   218.372
# 1                36       38         82           24          327    65.945
# 2                76       66         16           85           34   161.927
# 3                37       80         32           29            2   351.399
# 4                64       79         35            7            1   320.280
# ..              ...      ...        ...          ...          ...       ...
# 81               44       40         38           65           18   170.523
# 82               78       55         11           84            7   198.874
# 83                5       14         85           11           43   174.477
# 84               35       51         66           27          272    81.797
# 85               84       83          9           25            1   539.213
#
#     Area  Pop1831
# 0   5762   346.03
# 1   7369   513.00
# 2   7340   298.26
# 3   6925   155.90
# 4   5549   129.10
# ..   ...      ...
# 81  6990   282.73
# 82  5520   285.13
# 83  5874   397.99
# 84  7427   352.49
# 85  8680   195.41
#
# [86 rows x 23 columns]

# %% [markdown]
# Lets explore and see if literacy rates are associated with per capita entries in the Royal Lottery. Our model will need to control for wealth in each region, as well as utilize dummy variables to control for unobserved heterogeneity due to regional effects.
#
# We will use OLS to estimate this model, as described below:
#
# $$\hat{\beta} = (X'X)^{-1}X'y$$
#
# Where $y$ is a $N * 1$ column of per-capita lottery wagers (Lottery), while $X$ is an $N * 7$ matrix with a constant, literacy, wealth, and 4 regional dummy variables.

# %% [markdown]
# To actually implement this model, there are a couple options, especially with regards to how we could encode the dummy variables.

# %% [markdown]
# ## TODO
#
# Finish basic intro + modified model excercise

# %% [markdown]
# ##         Example: Contingent valuation

# %% [markdown]
# The file <code>LoomistForestCVDataset.csv</code> contains a subset of the dataset used by Loomis et al. (1996). The dataset consists of five columns. The first column lists a bid amount randomly proposed to a respondent to assess their willingness to pay for a fire management program for old growth Pacific Northwest forests. The second column lists the number of respondents saying yes to the project under version one of the survey. The third column lists the number of respondents saying no to the project under version one of the survey. Columns four and five give yes and no responses for the same bid amount but under a different version of the survey.

# %%
loomisCVD = pd.read_csv("LoomisCVData.csv")
loomisCVD
# Out:
#     BidAmount  NumYes_v1  NumNo_v1  NumYes_v2  NumNo_v2
# 0           2          3         2          8         1
# 1           5          6         2          7         1
# 2           8          4         1          5         4
# 3          10          5         1          8         2
# 4          12          6         4          7         1
# 5          15         10         0          4         1
# 6          20          6         1          3         2
# 7          25          0         1          2         1
# 8          30          3         1          5         0
# 9          35          3         2          6         0
# 10         40          4         2          2         0
# 11         50          3         2          4         2
# 12         60          4         6          4         5
# 13         70          1        10          2         5
# 14         80          2         3          2         5
# 15         90          3         3          4         3
# 16        120          3         0          3         4
# 17        150          1         6          3         4
# 18        200          2         2          1         7
# 19        300          0         8          0         6

# %% [markdown]
# 1. Lets begin by writing a short Python script to transform the given datafile into one respondent per row form. The first column should equal $D = 1$ if the respondent answered yes, $D = 0$ if they answered no. The second column should give the bid amount, $A$. The third column is $X = 1$ if the response was solicited from version one of the survey and $X = 0$ if it was from version two.

# %%
def transform_data(df):
    D_ = []
    A_ = []
    X_ = []
    
    def add_trow(d, a, x):
        D_.append(d)
        A_.append(a)
        X_.append(x)

    for index, row in df.iterrows():
        b = row['BidAmount']
        for i in range(row['NumYes_v1']):
            add_trow(1,b,1)
        for i in range(row['NumNo_v1']):
            add_trow(0,b,1)
        for i in range(row['NumYes_v2']):
            add_trow(1,b,0)
        for i in range(row['NumNo_v2']):
            add_trow(0,b,0)
            
    return pd.DataFrame(columns=['D', 'A', 'X'], data=np.array([D_, A_, X_]).T)

# %%
cvd_transformed = transform_data(loomisCVD)

### transformed data set
print(cvd_transformed)
# Out:
#      D    A  X
# 0    1    2  1
# 1    1    2  1
# 2    1    2  1
# 3    0    2  1
# 4    0    2  1
# ..  ..  ... ..
# 255  0  300  0
# 256  0  300  0
# 257  0  300  0
# 258  0  300  0
# 259  0  300  0
#
# [260 rows x 3 columns]

# %% [markdown]
# 2. Let's assume that willingness-to-pay for the fire management program for a randomly sampled person is: $$ W = \alpha + X'\beta + V$$ where $V | X, A ∼ \it  \mathcal{N}(0, \sigma^2)$ captures heterogeneity in willingness-to-pay across individuals.
#
# (Is this assumption robust? See errata)

# %% [markdown]
# 3. Assume that individuals respond yes to the proposal if their willingness-to-pay exceeds the bid they were offered. Then:
#
# $$Pr (D = 1| X, A) = \Phi\left(\frac \alpha \sigma - \frac 1 \sigma A + X' \frac \beta \sigma \right)$$ with $\Phi(*)$ the CDF of the standard normal distribution.
#
# (See errata for proof)

# %% [markdown]
# 4. Use probit regression analysis to construct estimates of the composite parameters $\frac \alpha \sigma$, $- \frac 1 \sigma$, $\frac \beta \sigma$. From these estimates recover estimates of the fundamental preference parameters $\alpha$, $\beta$ and $\sigma$. Describe and implement a bootstrap procedure to construct standard error estimates for these parameters. Summarize you results in a table and provide a brief discussion.

# %%
#define endog, explanatory variables
X = sm.add_constant(cvd_transformed[['A', 'X']])
y = cvd_transformed['D']

#probit model
probit_model = sm.Probit(y, X)
results = probit_model.fit()
param_estimates = results.params
print(param_estimates)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-367d0db15991> in <module>
#       1 #define endog, explanatory variables
# ----> 2 X = sm.add_constant(cvd_transformed[['A', 'X']])
#       3 y = cvd_transformed['D']
#       4
#       5 #probit model
#
# NameError: name 'sm' is not defined

# %%
### Bootstrap Procedure: Probit on const, A, X

B = 1000
N = 260

def param_bootstrap(df):
    const = []
    A_ = []
    X_ = []
    for i in range(B):
        
        sample_df = df.sample(n=N, replace=True)
        
        # probit procedure from earlier
        X = sm.add_constant(sample_df[['A', 'X']])
        y = sample_df['D']
        
        probit_model = sm.Probit(y, X)
        results = probit_model.fit()
        
        const.append(results.params['const'])
        A_.append(results.params['A'])
        X_.append(results.params['X'])
    return pd.DataFrame(columns=['alpha', 'sigma', 'beta'], data=np.array([const, A_, X_]).T)

# %%
bootstrap_param_results = param_bootstrap(cvd_transformed)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.577221
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569174
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.612461
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564103
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.621720
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.566042
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.578533
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.568896
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.615288
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596924
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.526020
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.576330
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.533896
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.613167
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564324
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.600875
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.554545
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564090
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592700
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.588800
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.579244
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.588743
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.566279
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564378
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543897
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561976
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.597847
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.520333
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.578371
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.563710
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593484
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.558869
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561143
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.583198
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.506140
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580309
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590270
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.585300
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.535222
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.585466
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.613321
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.582294
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.613053
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.549320
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.544039
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.567197
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.586606
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.587896
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.535566
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561466
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.558301
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581296
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541088
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.614316
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.585765
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.538491
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.563592
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.617716
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.577854
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.545768
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.545416
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569835
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564789
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569465
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.590659
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.600836
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.617209
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580765
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.595981
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.558503
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570559
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.597345
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.541838
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.596191
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.535379
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542873
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564874
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.539008
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.544005
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.533256
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564973
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596096
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.581961
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.568308
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.586867
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581992
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592508
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579258
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.560672
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.557383
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.555799
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.588460
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.547417
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.539062
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.612357
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.546062
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.565004
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564359
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605495
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583850
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.485107
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605986
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.536157
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.567958
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.597908
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.595021
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.521503
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.534856
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.576497
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.565108
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.606718
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.530645
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.557808
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.568807
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.557549
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.611108
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.612812
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.546930
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569529
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.562320
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.481387
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581803
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569112
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.554968
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564485
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.522230
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529238
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.509021
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.525549
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.590168
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.556628
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.568224
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.537647
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570841
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581810
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.571077
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.595717
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593194
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582820
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.535302
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.576410
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.594407
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.601070
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.568629
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.594901
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570169
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.563891
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.574171
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.571812
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.547752
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.535219
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.548665
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.587427
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.601594
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.553529
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.566037
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603917
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.611866
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.625490
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.508592
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.553878
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570408
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.594450
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.517030
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.548851
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.529399
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.574407
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.585827
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.597167
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.587397
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.590450
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.568364
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561132
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543400
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551421
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575194
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.563597
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570609
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.589913
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.513773
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582817
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604888
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.549689
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.526411
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.594457
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.531482
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.550122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592278
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.568665
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.573104
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.596444
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.590409
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.555675
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.558165
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579800
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.597305
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.556749
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.557602
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.615261
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.582317
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542867
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604783
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.587248
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.508271
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.545817
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.550307
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.595657
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598284
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.569003
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.538152
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.597132
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579989
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.568936
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.588607
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.614262
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.583337
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543213
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579768
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.584715
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588990
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.524674
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.537284
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.525497
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.586996
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.596469
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.550303
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570841
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561261
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.532153
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.525234
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.578956
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543999
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577025
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.540843
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.560050
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540647
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.557936
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.559377
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543704
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.583617
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.601387
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.544928
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582158
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.511923
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603327
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.578674
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.596202
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.537500
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.547900
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581552
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580169
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561496
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.559275
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.611123
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591372
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.583713
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.548609
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542334
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.566354
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.547437
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.525305
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.568376
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.540797
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.599491
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.604916
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.544358
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591131
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.574375
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.558375
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.598594
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.575390
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.556721
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.528504
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.563554
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570399
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.559426
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.574257
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.552850
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564311
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577779
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.570720
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.573368
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580601
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.589175
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.583742
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.528122
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.600892
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.588424
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.537883
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.579097
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.594418
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.580574
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.507021
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580682
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542148
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.594522
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.586126
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.579313
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.546256
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.546066
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.554537
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.546526
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605387
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579212
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.573596
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.602024
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.585623
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.556656
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.599615
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.556716
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.585055
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.566412
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.557675
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.572596
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.555233
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580337
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569961
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.554365
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.540268
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.527265
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.559772
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.552588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.587033
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.618497
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.590703
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.568571
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.608267
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.565312
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.573684
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.568198
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.549114
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.558458
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.554626
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603838
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593343
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.558175
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588712
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603337
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600399
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.532704
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.583919
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.579873
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.578716
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580018
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.535632
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589806
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.609830
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.573594
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.552582
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.558712
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.530071
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.607107
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.527205
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.574528
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580119
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570433
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.522720
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543810
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561516
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.558282
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.614768
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564062
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.579448
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.524049
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.574680
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.582855
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.618431
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.584598
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564211
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575374
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592202
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.568234
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.521141
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542374
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.535576
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.537056
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575818
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.527892
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.583071
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.540344
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.618160
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.616431
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.598723
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.532831
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.555749
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.592515
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.552265
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604998
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.588419
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.566554
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569557
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.571065
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.582722
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.630971
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.542653
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605491
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.566960
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.589427
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.614135
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.475531
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.546326
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.566067
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.533118
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540557
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.536155
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581674
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.567968
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.560367
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.534015
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.574139
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.591525
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581964
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.611466
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589607
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.589973
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.560947
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.518681
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.588470
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.563317
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.579447
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.592144
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.589298
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.569894
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.522133
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580350
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604728
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.600991
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.576678
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580161
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.515170
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581527
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.549216
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577961
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.585245
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.586027
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.595463
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.592161
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.569913
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.588280
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.536386
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.537360
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.602139
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569824
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.565059
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.562341
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.548281
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.618073
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579630
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.556855
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.590698
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.516235
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564986
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.572656
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543999
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.598703
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.496763
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577131
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.562582
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.571530
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.588278
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.577362
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.579620
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.514476
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580640
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.542802
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.584919
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551643
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564532
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575707
#          Iterations 6
# Optimization terminated successfully.
# ...
#          Current function value: 0.561891
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.498871
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.525905
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.588078
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.574656
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.579571
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.585171
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.613253
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.582960
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.556395
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570229
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543886
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.556656
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.563861
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.576137
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.601107
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.538088
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.514317
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.572572
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.559866
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.554162
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.572413
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569242
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575684
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.568564
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.571361
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.532417
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551933
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.603876
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.574888
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.572420
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.563250
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.576543
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.567154
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.570714
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.551501
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.528372
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.631198
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.579975
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.550345
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.567325
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.584604
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.575451
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.581127
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.568545
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582910
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.562244
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.539235
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.526237
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.552283
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581336
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.552046
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.578394
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.583467
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.523060
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575804
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.528866
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.575683
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569382
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.518534
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.549160
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.525977
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.539948
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.616200
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.535453
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.559276
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.566947
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564764
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.594589
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.573883
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.528734
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.576348
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.508278
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.610416
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.541248
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.548421
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.566132
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.542360
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.589039
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.610977
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.552163
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.580836
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.561363
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.539014
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.515028
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.533724
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.596451
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.563897
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.535987
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.614723
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.568283
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.573872
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.574484
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564029
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.549588
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.621877
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.582234
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.562271
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.608083
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.578441
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.547485
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569650
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.599169
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.480621
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.566232
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.581614
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.582873
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.555362
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.573813
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.563700
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593625
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.531481
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.535502
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.631382
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.547782
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.587924
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604696
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.576125
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569534
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593049
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.572611
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.590558
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.575277
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.530788
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.530224
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.566358
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.561050
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.553610
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.598319
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.558278
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.527358
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.545051
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.555338
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.556040
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.519412
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.558870
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.562315
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.531772
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.530660
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.574752
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.606824
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.588275
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.575528
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.604551
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.548654
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.555775
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.605318
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.569486
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.572435
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.527484
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.532846
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.576109
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.551565
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.593689
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.545136
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.565840
#          Iterations 6

# %%
#estimated parameters
estimate_sigma = -(1 / param_estimates['A'])
estimate_beta = estimate_sigma * param_estimates['X']
estimate_alpha = estimate_sigma * param_estimates['const']

#estimated parameters from boot strap
sigma_bs = -(1/bootstrap_param_results['sigma'])
beta_bs = bootstrap_param_results['beta'] * sigma_bs
alpha_bs = sigma_bs * bootstrap_param_results['alpha']

bs_params=pd.DataFrame(columns=['alpha', 'sigma', 'beta'], data=np.array([alpha_bs, sigma_bs, beta_bs]).T)

print(estimate_alpha,estimate_sigma, estimate_beta)
print(bs_params.describe())
# Out:
# 89.93127075029903 104.96104077116776 -16.864657183530923
#              alpha        sigma         beta
# count  1000.000000  1000.000000  1000.000000
# mean     89.759382   104.632860   -16.721134
# std      13.465770    16.759658    18.233961
# min      55.268984    59.705079   -74.850496
# 25%      80.600313    92.855216   -29.356307
# 50%      89.257741   103.921370   -16.895612
# 75%      98.753326   114.438039    -5.370041
# max     137.295144   166.904707    55.173546

# %% [markdown]
# Our recovered parameters from our probit regression onto the dataset is:
#
# $$\hat{\alpha} = 89.93$$
# $$\hat{\sigma} = 104.96$$
# $$\hat{\beta} = -16.86$$
#
# Our bootstrap recovered params have the characteristics as shown in the table above, with recovered standard errors as follows:
#
# $$SE(\hat{\alpha})  = 13.22 $$
# $$SE(\hat{\sigma}) = 17.44 $$
# $$SE(\hat{\beta}) = 17.80 $$

# %% [markdown]
# ### Discussion:
#
# Our results for the parameters were as expected; the sign of the coefficient on beta is interesting however. Loomis, in the literature, found no statistical difference between the two surveys. Indeed, although our computed coefficient on beta is less than zero, it falls well within a $0.05$-significance around zero (which indicates that we also found no statistical difference between the surveys, as our confidence band would be $[-35.6, 35.6]$, which our computed beta falls within). Thus our results fall in line with what was expected both from the literature and intuitively (such as higher bid prices indicating lower probability of support).

# %% [markdown]
# You are part of an environmental conservation group that is campaigning for a ballot initiative that would fund a fire management program like the one studied by Loomis et al. (1996). The type of initiative you wrote needs to pass with a majority of 67 percent. Your organization wrote the ballot initiative with a proposed tax of $\hat{A}^{∗} −0.05$ per person, with $\hat{A}^{∗}$ equal to $$ \hat{A}^{∗} = \hat{\alpha} − \hat{\sigma}\Phi^{-1}(0.67)$$ Here $\hat{\alpha}$ and $\hat{\sigma}$ correspond to your point estimates from question 4 above. Explain the
# reasoning behind choosing the proposed tax in this way? Construct an estimate of this
# tax (as well as a standard error using the bootstrap).

# %%
from scipy.stats import norm

tax_estimate = estimate_alpha - estimate_sigma*norm.ppf(0.67) - 0.05
print(tax_estimate)
# Out:
# 43.70752703229726

# %%
### Bootstrap Procedure: Tax = A^* - 0.05*

B = 10000
N = 260
def a_est_bootstrap(df):
    
    a_hats = []
    
    for i in range(B):
        
        #sample with replacement
        sample_df = df.sample(n=N, replace=True)
        
        X = sm.add_constant(sample_df[['A', 'X']])
        y = sample_df['D']
        
        probit_model = sm.Probit(y, X)
        results = probit_model.fit()
        
        sigma_hat = -(1 / results.params['A'])
        alpha_hat = sigma_hat * results.params['const']
        
        a_hat_estimate = alpha_hat - (sigma_hat*norm.ppf(0.67)) - 0.05
        a_hats.append(a_hat_estimate)
        
    return pd.DataFrame(columns=['a_hat'], data=np.array([a_hats]).T)

# %%
a_hat_bs = a_est_bootstrap(cvd_transformed)
a_hat_bs

# %%
print(a_hat_estimate)
print(a_hat_bs.describe())
# Out:
# 43.70752703229727
#               a_hat
# count  10000.000000
# mean      43.499230
# std       12.815674
# min      -17.709199
# 25%       35.109533
# 50%       43.667682
# 75%       52.098677
# max       97.761347

# %% [markdown]
# We construct the tax in this fashion in order to target the WTP of at least $67\%$ of the population (i.e. to find the tax-level that is less than or equal to the WTP of at least $67\%$ of the population). This is ensured by the $\hat{\sigma}\Phi^{-1}(0.67)$ term, as it basically moves $\hat{\alpha}$ (the mean willingness to pay) by the amount needed to capture $67\%$ of the sampled population willingness to pay.
#
# We find our estimate of the tax to be: $43.70$ and the standard error via bootstrap to be $12.81$ as shown in the result above.

# %% [markdown]
# <a class="anchor" id="rs"></a>
# ### Reference Sheets!
# [Back to Table of Contents](#tof)
#
# Links updated as of 1/1/11.
#
# - [NumPy Cheat Sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Numpy_Python_Cheat_Sheet.pdf)
# - [Pandas Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# - [Matplotlib Cheat Sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf)
# - [Seaborn Cheat Sheet](https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Seaborn_Cheat_Sheet.pdf)
#
# Documentation
#
# - [Statsmodels Docs](https://www.statsmodels.org/stable/index.html)
# - [Linearmodels Docs](https://bashtage.github.io/linearmodels/)

# %% [markdown]
# ### More Resources
# 1. Data Peer Consultants - That's us! We help undergrads and graduate students with projects, research, and more! Come to our drop-in hours.
# https://data.berkeley.edu/ds-peer-consulting
#
# 2. Towards Data Science - Website full of good blogs and helpful introductions to data science stuff.
# https://towardsdatascience.com/
#
# 3. Stack Overflow // Google - A great data scientist is adept at using StackOverflow and Google to find the answers to their bugs. More likely than not, someone out there has ran into the exact same problem as you, so might as well use their solutions as a resource!

# %% [markdown]
# ## Thanks for Coming! PLEASE COMPLETE THIS POST-WORKSHOP SURVEY!
# [TODO](https://forms.gle/gfuYbKTFEscnkrMY8)

# %% [markdown]
# ### Errata
#
# #### 2.
# The survey design ensures independence of $V$ and $X$ and $A$ as $X$ and $A$ are randomly assigned to the population without any selection critereon. More specifically, the general random selection of surveyees coupled with the further random assignment of $X$ (via survey version) ensures independence by construction.
#
# #### 3.
#
# We begin our analysis by examining the point of indifference between $W$ and $A$:
#
# $$A = W$$
#
# Standardize
#
# $$\frac A \sigma = \frac W \sigma$$
#
# Expand $W$
#
# $$\frac{A}{\sigma} = \frac{\alpha}{\sigma} + X^{'} \frac{\beta}{\sigma} + \frac{V}{\sigma}$$
#
# Normalize to mean zero:
#
# $$\frac{\alpha}{\sigma} - \frac{1}{\sigma} A + X^{'} \frac{\beta}{\sigma} + \frac{V}{\sigma}$$
#
# Let the above expression be $Y$. We realize that:
#
# $$Pr(D=1|X,A) = Pr(Y > 0 | X, A)$$
#
# Substituting:
#
# $$Pr(D=1|X,A) = Pr\left(\frac{\alpha}{\sigma} - \frac{1}{\sigma} A + X^{'} \frac{\beta}{\sigma} + \frac{V}{\sigma} > 0 | X, A \right)$$
#
#
# $$ = Pr\left(\frac{\alpha}{\sigma} - \frac{1}{\sigma} A + X^{'} \frac{\beta}{\sigma} + \frac{V}{\sigma}> 0 | X, A \right)$$
#
#
# $$ = Pr\left(\frac{V}{\sigma} > -\frac{\alpha}{\sigma} + \frac{1}{\sigma} A - X^{'} \frac{\beta}{\sigma}| X, A \right)$$
#
# By symmetry of the normal distribution and as $V | X, A ∼ \it  \mathcal{N}(0, \sigma^2)$:
#
# $$ = Pr\left(\frac{V}{\sigma} < \frac{\alpha}{\sigma} - \frac{1}{\sigma} A + X^{'} \frac{\beta}{\sigma}| X, A \right)$$
#
# Thus:
#
# $$ Pr(D=1|X,A) = \Phi\left(\frac{\alpha}{\sigma} - \frac{1}{\sigma} A + X^{'} \frac{\beta}{\sigma}\right)$$
